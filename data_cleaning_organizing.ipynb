# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import pymongo

pd.options.display.float_format = '{:.2f}'.format

# %%
df_cleaned_2000 = pd.read_csv('./df_cleaned_2000.csv')

# %%
df_cleaned_2000 = df_cleaned_2000.drop(columns=['Unnamed: 0', 'level_0'])

# %%
# Group by Sector, Date, calculate volume mean
sector_group = df_cleaned_2000.groupby(['sector','date'])
volume_mean = sector_group['volume'].mean()
sector_volume_mean = pd.DataFrame(volume_mean)
sector_volume_mean = sector_volume_mean.reset_index()
pd.options.display.float_format = "{:.2f}".format

# %%
# Pivot dataframe to view moving average of volume over 2 months
sector_volume_mean_pivot=sector_volume_mean.pivot(index='date',columns='sector')["volume"]

sector_volume_mean_pivot['BASIC INDUSTRIES MOVE-AVG'] = sector_volume_mean_pivot['BASIC INDUSTRIES'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['HEALTH CARE MOVE-AVG'] = sector_volume_mean_pivot['HEALTH CARE'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['CONSUMER DURABLES MOVE-AVG'] = sector_volume_mean_pivot['CONSUMER DURABLES'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['TECHNOLOGY MOVE-AVG'] = sector_volume_mean_pivot['TECHNOLOGY'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['CONSUMER SERVICES MOVE-AVG'] = sector_volume_mean_pivot['CONSUMER SERVICES'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['ENERGY MOVE-AVG'] = sector_volume_mean_pivot['ENERGY'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['MISCELLANEOUS MOVE-AVG'] = sector_volume_mean_pivot['MISCELLANEOUS'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['FINANCE MOVE-AVG'] = sector_volume_mean_pivot['FINANCE'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['CONSUMER NON-DURABLES MOVE-AVG'] = sector_volume_mean_pivot['CONSUMER NON-DURABLES'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['CAPITAL GOODS MOVE-AVG'] = sector_volume_mean_pivot['CAPITAL GOODS'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['PUBLIC UTILITIES MOVE-AVG'] = sector_volume_mean_pivot['PUBLIC UTILITIES'].rolling(window=63,center=False).mean()
sector_volume_mean_pivot['TRANSPORTATION MOVE-AVG'] = sector_volume_mean_pivot['TRANSPORTATION'].rolling(window=63,center=False).mean()

sector_volume_moving_mean_pivot=sector_volume_mean_pivot.iloc[:, 12:]

# %%
sector_volume_moving_mean_pivot = sector_volume_moving_mean_pivot.dropna(how="all")
sector_volume_moving_mean_pivot['date'] = sector_volume_moving_mean_pivot.index
sector_volume_moving_mean_pivot.head()
# Out:
# sector      BASIC INDUSTRIES MOVE-AVG  HEALTH CARE MOVE-AVG  \
# date
# 2000-03-31                  592974.44            1368719.59
# 2000-04-03                  594607.73            1365777.07
# 2000-04-04                  601931.40            1374591.62
# 2000-04-05                  601743.64            1378135.61
# 2000-04-06                  597757.97            1378349.76
#
# sector      CONSUMER DURABLES MOVE-AVG  TECHNOLOGY MOVE-AVG  \
# date
# 2000-03-31                   305539.95           3329918.83
# 2000-04-03                   306105.15           3335181.74
# 2000-04-04                   307744.15           3362986.04
# 2000-04-05                   307671.67           3348893.01
# 2000-04-06                   307519.90           3335527.10
#
# sector      CONSUMER SERVICES MOVE-AVG  ENERGY MOVE-AVG  \
# date
# 2000-03-31                   880135.07       1247111.33
# 2000-04-03                   879360.69       1249204.35
# 2000-04-04                   882257.88       1260342.59
# 2000-04-05                   877005.56       1259620.09
# 2000-04-06                   873546.63       1256236.71
#
# sector      MISCELLANEOUS MOVE-AVG  FINANCE MOVE-AVG  \
# date
# 2000-03-31              1706146.46         456946.05
# 2000-04-03              1697185.25         459041.81
# 2000-04-04              1726098.00         460498.00
# 2000-04-05              1714102.29         464631.55
# 2000-04-06              1715147.97         464727.57
#
# sector      CONSUMER NON-DURABLES MOVE-AVG  CAPITAL GOODS MOVE-AVG  \
# date
# 2000-03-31                       876070.10               506983.91
# 2000-04-03                       879850.70               507156.41
# 2000-04-04                       887077.60               510375.68
# 2000-04-05                       887641.05               509789.06
# 2000-04-06                       889148.11               508509.88
#
# sector      PUBLIC UTILITIES MOVE-AVG  TRANSPORTATION MOVE-AVG        date
# date
# 2000-03-31                  740973.81                793370.30  2000-03-31
# 2000-04-03                  739279.04                795954.62  2000-04-03
# 2000-04-04                  742232.06                798179.33  2000-04-04
# 2000-04-05                  741665.25                799006.87  2000-04-05
# 2000-04-06                  741702.61                795693.79  2000-04-06

# %%
# Export dataframe to CSV (read in via stock_data.py)
svm.to_csv('./svm.csv')

# %%
# top_growth_2000_2018 API data

# %%
# year 2000
Q1_vol = df_cleaned_2000['volume'].quantile(0.25)
Q3_vol = df_cleaned_2000['volume'].quantile(0.75)
vol_IQR = Q3_vol - Q1_vol

#Filter rows where volume is considered a low outlier
df_2000_no_out = df_cleaned_2000.loc[df_cleaned_2000['volume'] > Q1_vol]
df_2000_no_out = df_2000_no_out.reset_index(drop=True)

# Stock data beginning year 2000
df_cleaned_2000_boy = df_2000_no_out.loc[df_2000_no_out['date']=='2000-01-03']
df_cleaned_2000_boy = df_cleaned_2000_boy.reset_index()

# Stock data end year 2000
df_cleaned_2000_eoy = df_2000_no_out.loc[df_2000_no_out['date']=='2000-12-29']
df_cleaned_2000_eoy = df_cleaned_2000_eoy.reset_index()

# Combine beginning of year and end of year data
full_year_2000 = pd.merge(df_cleaned_2000_boy, df_cleaned_2000_eoy, on=['ticker'], how='inner')
full_year_2000 = full_year_2000[['ticker', 'name_x', 'exchange_x', 'sector_x', 'industry_x', 'date_x', 'open_x', 'close_x', 'adj_close_x', 'volume_x', 'date_y',  'open_y', 'close_y', 'adj_close_y', 'volume_y']]
full_year_2000['yearly_value_change'] = full_year_2000['adj_close_y'] - full_year_2000['open_x']
full_year_2000 = full_year_2000[['ticker', 'name_x', 'sector_x', 'yearly_value_change']]

# Best stocks in terms of per-share value from beginning of year to end of year
desc_2000_yearly_change = full_year_2000.sort_values(['yearly_value_change'],ascending=False)
pos_year_change_2000 = desc_2000_yearly_change[:100]
pos_year_change_2000 = pos_year_change_2000.reset_index(drop=True)

# %%
# Call the Yahoo! Finance API to obtain address for top 100 growth stocks for year 2000 and store in MongoDB 
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["stocks"]
mycol = mydb["data_2000"]

mydb.data_2000.drop()

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v2/get-summary"

headers = {
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com",
    'x-rapidapi-key': "087b501299msh74fbf4fc4582eaap1839cbjsn17adecb6e3c3"
    }

data = []

for ticker in pos_year_change_2000['ticker'].values:    
    try:
        querystring = {"region":"US","symbol":ticker}
        tick_response = requests.get(url, headers=headers, params=querystring).json()
        tick_response['summaryProfile']['address1'], tick_response['summaryProfile']['city']
    except:
        continue        
    try:
        address = tick_response['summaryProfile']['address1'], tick_response['summaryProfile']['city'], tick_response['summaryProfile']['state']
        address = ','.join(address)
    except KeyError as e:
        if e.args[0] == 'state':
            address = tick_response['summaryProfile']['address1'], tick_response['summaryProfile']['city'], tick_response['summaryProfile']['country']
            address = ','.join(address)
    
    # Call the Google GeoCode API to obtain coordinates for stock address
    target_url = f'https://maps.googleapis.com/maps/api/geocode/json?address={address}&key=AIzaSyDGlaG4puf-3NnoE9XGpSPgpAU92RAhzKE'
    geo_response = requests.get(target_url).json()
    city_lat = geo_response['results'][0]['geometry']['location']['lat']
    city_lng = geo_response['results'][0]['geometry']['location']['lng']
    
#     print(f'Ticker: {ticker}')
    
    data_dict = {
        "ticker": ticker,
        "name": pos_year_change_2000.loc[pos_year_change_2000['ticker'] == ticker]['name_x'].values[0],
        "yearly_value_change": pos_year_change_2000.loc[pos_year_change_2000['ticker'] == ticker]['yearly_value_change'].values[0],
        "sector": pos_year_change_2000.loc[pos_year_change_2000['ticker'] == ticker]['sector_x'].values[0],
        "latitude": city_lat,
        "longitude": city_lng,
        "date": 2000
    }
    
#     print(data_dict)
    data.append(data_dict)
    
for stock in data:
    mycol.insert_one(stock)

# %%
# year 2018

# %%
# Dataframe for stocks from Aug 2017 - Aug 2018
historical_stock_prices = pd.read_csv('historical_stock_prices.csv')
historical_stocks = pd.read_csv('historical_stocks.csv')

combined_stocks_df = pd.merge(historical_stock_prices, historical_stocks, on='ticker', how='inner')
currently_trading_ticker = combined_stocks_df.loc[combined_stocks_df['date'] == '2018-08-24']['ticker'].values
currently_trading_df = combined_stocks_df[combined_stocks_df['ticker'].isin(currently_trading_ticker)]
cleaned_currently_trading_df = currently_trading_df.dropna(axis=0)
sorted_current_trading = cleaned_currently_trading_df.sort_values(['date','ticker'])
sorted_current_trading = sorted_current_trading.reset_index()

df_cleaned_2018 = sorted_current_trading.loc[sorted_current_trading['date'] >= '2017-08-24']
df_cleaned_2018 = df_cleaned_2018.reset_index()
del df_cleaned_2018['index']
del df_cleaned_2018['level_0']
Q1_2018_vol = df_cleaned_2018['volume'].quantile(0.25)
df_2018_no_out = df_cleaned_2018.loc[df_cleaned_2018['volume'] > Q1_2018_vol]
df_2018_no_out = df_2018_no_out.reset_index(drop=True)

# Stock data beginning year Aug 2017
df_cleaned_2018_boy = df_2018_no_out.loc[df_2018_no_out['date']=='2017-08-24']
df_cleaned_2018_boy = df_cleaned_2018_boy.reset_index(drop=True)

# Stock data end year Aug 2018
df_cleaned_2018_eoy = df_2018_no_out.loc[df_2018_no_out['date']=='2018-08-24']
df_cleaned_2018_eoy = df_cleaned_2018_eoy.reset_index(drop=True)

# Beginning of 2017 year and end of 2018 year data
full_year_2018 = pd.merge(df_cleaned_2018_boy, df_cleaned_2018_eoy, on=['ticker'], how='inner')
full_year_2018 = full_year_2018[['ticker', 'name_x', 'exchange_x', 'sector_x', 'industry_x', 'date_x', 'open_x', 'close_x', 'adj_close_x', 'volume_x', 'date_y',  'open_y', 'close_y', 'adj_close_y', 'volume_y']]
full_year_2018['yearly_value_change'] = full_year_2018['adj_close_y'] - full_year_2018['open_x']
full_year_2018 = full_year_2018[['ticker', 'name_x', 'sector_x', 'yearly_value_change']]

# Best stocks in terms of per-share value from beginning of year to end of year
desc_2018_yearly_change = full_year_2018.sort_values(['yearly_value_change'],ascending=False)
pos_year_change_2018 = desc_2018_yearly_change[:100]
pos_year_change_2018 = pos_year_change_2018.reset_index(drop=False)
del pos_year_change_2018['index']

# %%
# Call the Yahoo! Finance API to obtain address for top 100 growth stocks for year 2018 and store in MongoDB 
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["stocks"]
mycol = mydb["data_2018"]

mydb.data_2018.drop()

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/v2/get-summary"

headers = {
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com",
    'x-rapidapi-key': '087b501299msh74fbf4fc4582eaap1839cbjsn17adecb6e3c3'
    }

data = []

for ticker in pos_year_change_2018['ticker'].values:    
    try:
        querystring = {"region":"US","symbol":ticker}
        tick_response = requests.get(url, headers=headers, params=querystring).json()
        tick_response['summaryProfile']['address1'], tick_response['summaryProfile']['city']
    except:
        continue        
    try:
        address = tick_response['summaryProfile']['address1'], tick_response['summaryProfile']['city'], tick_response['summaryProfile']['state']
        address = ','.join(address)
    except KeyError as e:
        if e.args[0] == 'state':
            address = tick_response['summaryProfile']['address1'], tick_response['summaryProfile']['city'], tick_response['summaryProfile']['country']
            address = ','.join(address)
    
    # Obtain coordinates for ticker address
    target_url = f'https://maps.googleapis.com/maps/api/geocode/json?address={address}&key=AIzaSyDGlaG4puf-3NnoE9XGpSPgpAU92RAhzKE'
    geo_response = requests.get(target_url).json()
    city_lat = geo_response['results'][0]['geometry']['location']['lat']
    city_lng = geo_response['results'][0]['geometry']['location']['lng']
    
    data_dict = {
        "ticker": ticker,
        "name": pos_year_change_2018.loc[pos_year_change_2018['ticker'] == ticker]['name_x'].values[0],
        "yearly_value_change": pos_year_change_2018.loc[pos_year_change_2018['ticker'] == ticker]['yearly_value_change'].values[0],
        "sector": pos_year_change_2018.loc[pos_year_change_2018['ticker'] == ticker]['sector_x'].values[0],
        "latitude": city_lat,
        "longitude": city_lng,
        "year": 2018
    }
    
    data.append(data_dict)
    
for stock in data:
    mycol.insert_one(stock)

# %%
mydb = myclient["stocks"]

stock_growth_data = []

for collection in mydb.list_collection_names():
    for row in mydb[collection].find({}, {"_id":0}):
        stock_growth_data.append(row)

# %%
stock_growth_data
# Out:
# [{'ticker': 'CIEN',
#   'name': 'CIENA CORPORATION',
#   'yearly_value_change': 364.4375,
#   'sector': 'PUBLIC UTILITIES',
#   'latitude': 39.1921521,
#   'longitude': -76.6999634,
#   'date': 2000},
#  {'ticker': 'TTNP',
#   'name': 'TITAN PHARMACEUTICALS, INC.',
#   'yearly_value_change': 89.70500183105402,
#   'sector': 'HEALTH CARE',
#   'latitude': 37.6652573,
#   'longitude': -122.3827431,
#   'date': 2000},
#  {'ticker': 'SANM',
#   'name': 'SANMINA CORPORATION',
#   'yearly_value_change': 78.9375,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.3900362,
#   'longitude': -121.9295653,
#   'date': 2000},
#  {'ticker': 'EMKR',
#   'name': 'EMCORE CORPORATION',
#   'yearly_value_change': 76.48147583007798,
#   'sector': 'TECHNOLOGY',
#   'latitude': 34.0821105,
#   'longitude': -118.1457295,
#   'date': 2000},
#  {'ticker': 'NVR',
#   'name': 'NVR, INC.',
#   'yearly_value_change': 75.849998474121,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 38.9519446,
#   'longitude': -77.3502091,
#   'date': 2000},
#  {'ticker': 'AIG',
#   'name': 'AMERICAN INTERNATIONAL GROUP, INC.',
#   'yearly_value_change': 74.09826660156,
#   'sector': 'FINANCE',
#   'latitude': 40.7063657,
#   'longitude': -74.0051548,
#   'date': 2000},
#  {'ticker': 'JNPR',
#   'name': 'JUNIPER NETWORKS, INC.',
#   'yearly_value_change': 59.608642578125,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.4074689,
#   'longitude': -122.0293159,
#   'date': 2000},
#  {'ticker': 'THC',
#   'name': 'TENET HEALTHCARE CORPORATION',
#   'yearly_value_change': 57.16667175292971,
#   'sector': 'HEALTH CARE',
#   'latitude': 32.7848396,
#   'longitude': -96.80269849999999,
#   'date': 2000},
#  {'ticker': 'WAT',
#   'name': 'WATERS CORPORATION',
#   'yearly_value_change': 56.875,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 42.136791,
#   'longitude': -71.4813247,
#   'date': 2000},
#  {'ticker': 'CHKP',
#   'name': 'CHECK POINT SOFTWARE TECHNOLOGIES LTD.',
#   'yearly_value_change': 54.8749961853028,
#   'sector': 'TECHNOLOGY',
#   'latitude': 32.0692701,
#   'longitude': 34.7960642,
#   'date': 2000},
#  {'ticker': 'VRTX',
#   'name': 'VERTEX PHARMACEUTICALS INCORPORATED',
#   'yearly_value_change': 53.75,
#   'sector': 'HEALTH CARE',
#   'latitude': 42.3534302,
#   'longitude': -71.0462,
#   'date': 2000},
#  {'ticker': 'CERS',
#   'name': 'CERUS CORPORATION',
#   'yearly_value_change': 48.25,
#   'sector': 'HEALTH CARE',
#   'latitude': 37.985649,
#   'longitude': -122.0472546,
#   'date': 2000},
#  {'ticker': 'EHC',
#   'name': 'ENCOMPASS HEALTH CORPORATION',
#   'yearly_value_change': 46.2432861328125,
#   'sector': 'HEALTH CARE',
#   'latitude': 33.477506,
#   'longitude': -86.704251,
#   'date': 2000},
#  {'ticker': 'LH',
#   'name': 'LABORATORY CORPORATION OF AMERICA HOLDINGS',
#   'yearly_value_change': 34.78125,
#   'sector': 'HEALTH CARE',
#   'latitude': 36.0931722,
#   'longitude': -79.4373797,
#   'date': 2000},
#  {'ticker': 'BLDP',
#   'name': 'BALLARD POWER SYSTEMS, INC.',
#   'yearly_value_change': 34.4062004089355,
#   'sector': 'ENERGY',
#   'latitude': 49.19812049999999,
#   'longitude': -123.0074482,
#   'date': 2000},
#  {'ticker': 'TIVO',
#   'name': 'TIVO CORPORATION',
#   'yearly_value_change': 31.360527038574205,
#   'sector': 'MISCELLANEOUS',
#   'latitude': 37.4194384,
#   'longitude': -121.9710837,
#   'date': 2000},
#  {'ticker': 'RE',
#   'name': 'EVEREST RE GROUP, LTD.',
#   'yearly_value_change': 31.329795837402287,
#   'sector': 'FINANCE',
#   'latitude': 32.3394323,
#   'longitude': -64.73742539999999,
#   'date': 2000},
#  {'ticker': 'BIIB',
#   'name': 'BIOGEN INC.',
#   'yearly_value_change': 30.3958320617676,
#   'sector': 'HEALTH CARE',
#   'latitude': 42.3662897,
#   'longitude': -71.0857637,
#   'date': 2000},
#  {'ticker': 'NKTR',
#   'name': 'NEKTAR THERAPEUTICS',
#   'yearly_value_change': 29.0625,
#   'sector': 'HEALTH CARE',
#   'latitude': 37.7704274,
#   'longitude': -122.3887624,
#   'date': 2000},
#  {'ticker': 'MYGN',
#   'name': 'MYRIAD GENETICS, INC.',
#   'yearly_value_change': 25.973197937011705,
#   'sector': 'HEALTH CARE',
#   'latitude': 40.7625221,
#   'longitude': -111.8258995,
#   'date': 2000},
#  {'ticker': 'C',
#   'name': 'CITIGROUP INC.',
#   'yearly_value_change': 25.78186035156199,
#   'sector': 'FINANCE',
#   'latitude': 40.72067819999999,
#   'longitude': -74.0111516,
#   'date': 2000},
#  {'ticker': 'DOX',
#   'name': 'AMDOCS LIMITED',
#   'yearly_value_change': 25.525352478027294,
#   'sector': 'TECHNOLOGY',
#   'latitude': 38.6482644,
#   'longitude': -90.5294009,
#   'date': 2000},
#  {'ticker': 'SBAC',
#   'name': 'SBA COMMUNICATIONS CORPORATION',
#   'yearly_value_change': 22.5,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 26.4197491,
#   'longitude': -80.0960051,
#   'date': 2000},
#  {'ticker': 'REGN',
#   'name': 'REGENERON PHARMACEUTICALS, INC.',
#   'yearly_value_change': 22.078098297119105,
#   'sector': 'HEALTH CARE',
#   'latitude': 41.0785443,
#   'longitude': -73.8234767,
#   'date': 2000},
#  {'ticker': 'SRDX',
#   'name': 'SURMODICS, INC.',
#   'yearly_value_change': 21.3125,
#   'sector': 'HEALTH CARE',
#   'latitude': 44.8694285,
#   'longitude': -93.4037094,
#   'date': 2000},
#  {'ticker': 'DGX',
#   'name': 'QUEST DIAGNOSTICS INCORPORATED',
#   'yearly_value_change': 21.282693862915,
#   'sector': 'HEALTH CARE',
#   'latitude': 40.7878337,
#   'longitude': -74.04492979999999,
#   'date': 2000},
#  {'ticker': 'PKI',
#   'name': 'PERKINELMER, INC.',
#   'yearly_value_change': 21.281635284423793,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 42.4047616,
#   'longitude': -71.2742976,
#   'date': 2000},
#  {'ticker': 'RMBS',
#   'name': 'RAMBUS, INC.',
#   'yearly_value_change': 18.625,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.4045818,
#   'longitude': -122.0360211,
#   'date': 2000},
#  {'ticker': 'PLT',
#   'name': 'PLANTRONICS, INC.',
#   'yearly_value_change': 17.219522476196193,
#   'sector': 'PUBLIC UTILITIES',
#   'latitude': 36.9864486,
#   'longitude': -122.036476,
#   'date': 2000},
#  {'ticker': 'MTD',
#   'name': 'METTLER-TOLEDO INTERNATIONAL, INC.',
#   'yearly_value_change': 16.375,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 40.1439863,
#   'longitude': -82.9690578,
#   'date': 2000},
#  {'ticker': 'IMGN',
#   'name': 'IMMUNOGEN, INC.',
#   'yearly_value_change': 15.9375,
#   'sector': 'HEALTH CARE',
#   'latitude': 42.4017924,
#   'longitude': -71.27829179999999,
#   'date': 2000},
#  {'ticker': 'ATGE',
#   'name': 'ADTALEM GLOBAL EDUCATION INC.',
#   'yearly_value_change': 15.817882537841804,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 41.8808419,
#   'longitude': -87.64076949999999,
#   'date': 2000},
#  {'ticker': 'UHS',
#   'name': 'UNIVERSAL HEALTH SERVICES, INC.',
#   'yearly_value_change': 15.7773456573486,
#   'sector': 'HEALTH CARE',
#   'latitude': 40.0790198,
#   'longitude': -75.37312349999999,
#   'date': 2000},
#  {'ticker': 'AXTI',
#   'name': 'AXT INC',
#   'yearly_value_change': 15.1875,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.5072674,
#   'longitude': -121.9573958,
#   'date': 2000},
#  {'ticker': 'QGEN',
#   'name': 'QIAGEN N.V.',
#   'yearly_value_change': 14.266313552856406,
#   'sector': 'HEALTH CARE',
#   'latitude': 51.34842090000001,
#   'longitude': 6.155257499999999,
#   'date': 2000},
#  {'ticker': 'TDY',
#   'name': 'TELEDYNE TECHNOLOGIES INCORPORATED',
#   'yearly_value_change': 14.0625,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 34.1974847,
#   'longitude': -118.9054586,
#   'date': 2000},
#  {'ticker': 'ASGN',
#   'name': 'ASGN INCORPORATED',
#   'yearly_value_change': 13.59375,
#   'sector': 'TECHNOLOGY',
#   'latitude': 34.138352,
#   'longitude': -118.7061768,
#   'date': 2000},
#  {'ticker': 'IVC',
#   'name': 'INVACARE CORPORATION',
#   'yearly_value_change': 13.4914360046387,
#   'sector': 'HEALTH CARE',
#   'latitude': 41.3725133,
#   'longitude': -82.0711972,
#   'date': 2000},
#  {'ticker': 'PWR',
#   'name': 'QUANTA SERVICES, INC.',
#   'yearly_value_change': 13.3541698455811,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 29.7370769,
#   'longitude': -95.46221829999999,
#   'date': 2000},
#  {'ticker': 'SEIC',
#   'name': 'SEI INVESTMENTS COMPANY',
#   'yearly_value_change': 13.111505508422894,
#   'sector': 'FINANCE',
#   'latitude': 40.1414246,
#   'longitude': -75.4473028,
#   'date': 2000},
#  {'ticker': 'NTAP',
#   'name': 'NETAPP, INC.',
#   'yearly_value_change': 12.987014770507791,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.4149198,
#   'longitude': -122.0095977,
#   'date': 2000},
#  {'ticker': 'MDT',
#   'name': 'MEDTRONIC PLC',
#   'yearly_value_change': 12.835006713867209,
#   'sector': 'HEALTH CARE',
#   'latitude': 53.3336406,
#   'longitude': -6.257194399999999,
#   'date': 2000},
#  {'ticker': 'BLK',
#   'name': 'BLACKROCK, INC.',
#   'yearly_value_change': 12.662181854248,
#   'sector': 'FINANCE',
#   'latitude': 40.75923909999999,
#   'longitude': -73.97354829999999,
#   'date': 2000},
#  {'ticker': 'RDN',
#   'name': 'RADIAN GROUP INC.',
#   'yearly_value_change': 12.3418769836426,
#   'sector': 'FINANCE',
#   'latitude': 39.9522839,
#   'longitude': -75.1662022,
#   'date': 2000},
#  {'ticker': 'TTEK',
#   'name': 'TETRA TECH, INC.',
#   'yearly_value_change': 12.016592025756902,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 34.1506329,
#   'longitude': -118.0781576,
#   'date': 2000},
#  {'ticker': 'STT',
#   'name': 'STATE STREET CORPORATION',
#   'yearly_value_change': 11.9580268859863,
#   'sector': 'FINANCE',
#   'latitude': 42.3528926,
#   'longitude': -71.0587436,
#   'date': 2000},
#  {'ticker': 'ADBE',
#   'name': 'ADOBE SYSTEMS INCORPORATED',
#   'yearly_value_change': 11.9177570343018,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.3303074,
#   'longitude': -121.8941558,
#   'date': 2000},
#  {'ticker': 'JKHY',
#   'name': 'JACK HENRY & ASSOCIATES, INC.',
#   'yearly_value_change': 11.899917602539102,
#   'sector': 'TECHNOLOGY',
#   'latitude': 36.9141117,
#   'longitude': -93.93882699999999,
#   'date': 2000},
#  {'ticker': 'AEGN',
#   'name': 'AEGION CORP',
#   'yearly_value_change': 11.6875,
#   'sector': 'BASIC INDUSTRIES',
#   'latitude': 38.6956445,
#   'longitude': -90.28938389999999,
#   'date': 2000},
#  {'ticker': 'GCO',
#   'name': 'GENESCO INC.',
#   'yearly_value_change': 11.4375,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 36.1132048,
#   'longitude': -86.6923245,
#   'date': 2000},
#  {'ticker': 'KSS',
#   'name': 'KOHL&#39;S CORPORATION',
#   'yearly_value_change': 11.410781860351598,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 43.121978,
#   'longitude': -88.12319,
#   'date': 2000},
#  {'ticker': 'SNV',
#   'name': 'SYNOVUS FINANCIAL CORP.',
#   'yearly_value_change': 11.345893859863303,
#   'sector': 'FINANCE',
#   'latitude': 32.4675029,
#   'longitude': -84.9956842,
#   'date': 2000},
#  {'ticker': 'NBR',
#   'name': 'NABORS INDUSTRIES LTD.',
#   'yearly_value_change': 11.1628398895264,
#   'sector': 'ENERGY',
#   'latitude': 32.2954168,
#   'longitude': -64.78838619999999,
#   'date': 2000},
#  {'ticker': 'SKYW',
#   'name': 'SKYWEST, INC.',
#   'yearly_value_change': 10.637359619140598,
#   'sector': 'TRANSPORTATION',
#   'latitude': 37.1006483,
#   'longitude': -113.5569325,
#   'date': 2000},
#  {'ticker': 'PXD',
#   'name': 'PIONEER NATURAL RESOURCES COMPANY',
#   'yearly_value_change': 10.3746356964111,
#   'sector': 'ENERGY',
#   'latitude': 32.8703634,
#   'longitude': -96.9395894,
#   'date': 2000},
#  {'ticker': 'AMG',
#   'name': 'AFFILIATED MANAGERS GROUP, INC.',
#   'yearly_value_change': 10.215728759765604,
#   'sector': 'FINANCE',
#   'latitude': 26.7066139,
#   'longitude': -80.0501742,
#   'date': 2000},
#  {'ticker': 'LUV',
#   'name': 'SOUTHWEST AIRLINES COMPANY',
#   'yearly_value_change': 10.125430107116701,
#   'sector': 'TRANSPORTATION',
#   'latitude': 32.7766642,
#   'longitude': -96.79698789999999,
#   'date': 2000},
#  {'ticker': 'TMO',
#   'name': 'THERMO FISHER SCIENTIFIC INC',
#   'yearly_value_change': 9.716579437255898,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 42.3929224,
#   'longitude': -71.26159430000001,
#   'date': 2000},
#  {'ticker': 'SM',
#   'name': 'SM ENERGY COMPANY',
#   'yearly_value_change': 9.6493873596191,
#   'sector': 'ENERGY',
#   'latitude': 39.7445109,
#   'longitude': -104.9851612,
#   'date': 2000},
#  {'ticker': 'SIVB',
#   'name': 'SVB FINANCIAL GROUP',
#   'yearly_value_change': 9.515649795532198,
#   'sector': 'FINANCE',
#   'latitude': 37.4042585,
#   'longitude': -121.982235,
#   'date': 2000},
#  {'ticker': 'MRCY',
#   'name': 'MERCURY SYSTEMS INC',
#   'yearly_value_change': 9.428287506103494,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 42.68763269999999,
#   'longitude': -71.21684429999999,
#   'date': 2000},
#  {'ticker': 'IMMU',
#   'name': 'IMMUNOMEDICS, INC.',
#   'yearly_value_change': 9.0,
#   'sector': 'HEALTH CARE',
#   'latitude': 40.8238847,
#   'longitude': -74.4765583,
#   'date': 2000},
#  {'ticker': 'APA',
#   'name': 'APACHE CORPORATION',
#   'yearly_value_change': 8.9986000061035,
#   'sector': 'ENERGY',
#   'latitude': 29.74534419999999,
#   'longitude': -95.46260319999999,
#   'date': 2000},
#  {'ticker': 'PTEN',
#   'name': 'PATTERSON-UTI ENERGY, INC.',
#   'yearly_value_change': 8.9918394088745,
#   'sector': 'ENERGY',
#   'latitude': 29.9206768,
#   'longitude': -95.5580363,
#   'date': 2000},
#  {'ticker': 'MBI',
#   'name': 'MBIA, INC.',
#   'yearly_value_change': 8.9915161132813,
#   'sector': 'FINANCE',
#   'latitude': 41.024784,
#   'longitude': -73.7193424,
#   'date': 2000},
#  {'ticker': 'MANH',
#   'name': 'MANHATTAN ASSOCIATES, INC.',
#   'yearly_value_change': 8.7265750169754,
#   'sector': 'TECHNOLOGY',
#   'latitude': 33.9059932,
#   'longitude': -84.4601722,
#   'date': 2000},
#  {'ticker': 'AGN',
#   'name': 'ALLERGAN PLC.',
#   'yearly_value_change': 8.721736907959006,
#   'sector': 'HEALTH CARE',
#   'latitude': 53.4046221,
#   'longitude': -6.220203199999999,
#   'date': 2000},
#  {'ticker': 'DVN',
#   'name': 'DEVON ENERGY CORPORATION',
#   'yearly_value_change': 8.703201293945302,
#   'sector': 'ENERGY',
#   'latitude': 35.4669418,
#   'longitude': -97.5177018,
#   'date': 2000},
#  {'ticker': 'CI',
#   'name': 'CIGNA CORPORATION',
#   'yearly_value_change': 8.675710678100597,
#   'sector': 'HEALTH CARE',
#   'latitude': 41.8128862,
#   'longitude': -72.7469102,
#   'date': 2000},
#  {'ticker': 'ALXN',
#   'name': 'ALEXION PHARMACEUTICALS, INC.',
#   'yearly_value_change': 8.671875,
#   'sector': 'HEALTH CARE',
#   'latitude': 42.3510789,
#   'longitude': -71.04447809999999,
#   'date': 2000},
#  {'ticker': 'MCK',
#   'name': 'MCKESSON CORPORATION',
#   'yearly_value_change': 8.548755645752,
#   'sector': 'HEALTH CARE',
#   'latitude': 32.8976055,
#   'longitude': -96.9722025,
#   'date': 2000},
#  {'ticker': 'AES',
#   'name': 'THE AES CORPORATION',
#   'yearly_value_change': 8.444095611572287,
#   'sector': 'BASIC INDUSTRIES',
#   'latitude': 38.879629,
#   'longitude': -77.1126498,
#   'date': 2000},
#  {'ticker': 'TARO',
#   'name': 'TARO PHARMACEUTICAL INDUSTRIES LTD.',
#   'yearly_value_change': 8.328129768371578,
#   'sector': 'HEALTH CARE',
#   'latitude': 32.8134997,
#   'longitude': 35.0589721,
#   'date': 2000},
#  {'ticker': 'VAR',
#   'name': 'VARIAN MEDICAL SYSTEMS, INC.',
#   'yearly_value_change': 8.26204252243047,
#   'sector': 'HEALTH CARE',
#   'latitude': 37.4170321,
#   'longitude': -122.1428778,
#   'date': 2000},
#  {'ticker': 'NOV',
#   'name': 'NATIONAL OILWELL VARCO, INC.',
#   'yearly_value_change': 8.255044460296649,
#   'sector': 'ENERGY',
#   'latitude': 29.6916115,
#   'longitude': -95.5545889,
#   'date': 2000},
#  {'ticker': 'PLXS',
#   'name': 'PLEXUS CORP.',
#   'yearly_value_change': 8.140600204467802,
#   'sector': 'TECHNOLOGY',
#   'latitude': 44.18864000000001,
#   'longitude': -88.464244,
#   'date': 2000},
#  {'ticker': 'CTAS',
#   'name': 'CINTAS CORPORATION',
#   'yearly_value_change': 7.571666717529297,
#   'sector': 'CONSUMER NON-DURABLES',
#   'latitude': 39.3408406,
#   'longitude': -84.28298319999999,
#   'date': 2000},
#  {'ticker': 'NBIX',
#   'name': 'NEUROCRINE BIOSCIENCES, INC.',
#   'yearly_value_change': 7.125,
#   'sector': 'HEALTH CARE',
#   'latitude': 32.949844,
#   'longitude': -117.237481,
#   'date': 2000},
#  {'ticker': 'SCHL',
#   'name': 'SCHOLASTIC CORPORATION',
#   'yearly_value_change': 7.0293655395507955,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 40.7240463,
#   'longitude': -73.9983888,
#   'date': 2000},
#  {'ticker': 'EOG',
#   'name': 'EOG RESOURCES, INC.',
#   'yearly_value_change': 6.868242263793899,
#   'sector': 'ENERGY',
#   'latitude': 29.7588117,
#   'longitude': -95.3706871,
#   'date': 2000},
#  {'ticker': 'UNH',
#   'name': 'UNITEDHEALTH GROUP INCORPORATED',
#   'yearly_value_change': 6.677447319030799,
#   'sector': 'HEALTH CARE',
#   'latitude': 44.898716,
#   'longitude': -93.4437263,
#   'date': 2000},
#  {'ticker': 'MTH',
#   'name': 'MERITAGE CORPORATION',
#   'yearly_value_change': 6.625,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 33.618974,
#   'longitude': -111.8902082,
#   'date': 2000},
#  {'ticker': 'ALKS',
#   'name': 'ALKERMES PLC',
#   'yearly_value_change': 6.53125,
#   'sector': 'HEALTH CARE',
#   'latitude': 53.332691,
#   'longitude': -6.2473347,
#   'date': 2000},
#  {'ticker': 'DY',
#   'name': 'DYCOM INDUSTRIES, INC.',
#   'yearly_value_change': 6.5208339691162,
#   'sector': 'BASIC INDUSTRIES',
#   'latitude': 37.2266918,
#   'longitude': -77.4013696,
#   'date': 2000},
#  {'ticker': 'CKH',
#   'name': 'SEACOR HOLDINGS, INC.',
#   'yearly_value_change': 6.374362945556605,
#   'sector': 'TRANSPORTATION',
#   'latitude': 26.0830109,
#   'longitude': -80.1155381,
#   'date': 2000},
#  {'ticker': 'RHI',
#   'name': 'ROBERT HALF INTERNATIONAL INC.',
#   'yearly_value_change': 6.249187469482397,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.4219437,
#   'longitude': -122.2151303,
#   'date': 2000},
#  {'ticker': 'CLGX',
#   'name': 'CORELOGIC, INC.',
#   'yearly_value_change': 6.185780525207568,
#   'sector': 'TECHNOLOGY',
#   'latitude': 33.6506498,
#   'longitude': -117.7517227,
#   'date': 2000},
#  {'ticker': 'FORR',
#   'name': 'FORRESTER RESEARCH, INC.',
#   'yearly_value_change': 6.1489791870117045,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 42.3982665,
#   'longitude': -71.14900589999999,
#   'date': 2000},
#  {'ticker': 'AMZN',
#   'name': 'AMAZON.COM, INC.',
#   'yearly_value_change': 947.9700317382841,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 47.6221942,
#   'longitude': -122.3365534,
#   'year': 2018},
#  {'ticker': 'GOOGL',
#   'name': 'ALPHABET INC.',
#   'yearly_value_change': 293.0399780273441,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.4222557,
#   'longitude': -122.0847653,
#   'year': 2018},
#  {'ticker': 'GOOG',
#   'name': 'ALPHABET INC.',
#   'yearly_value_change': 291.9900512695291,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.4222557,
#   'longitude': -122.0847653,
#   'year': 2018},
#  {'ticker': 'AZO',
#   'name': 'AUTOZONE, INC.',
#   'yearly_value_change': 256.850036621094,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 35.1420009,
#   'longitude': -90.0561333,
#   'year': 2018},
#  {'ticker': 'ABMD',
#   'name': 'ABIOMED, INC.',
#   'yearly_value_change': 227.72000122070304,
#   'sector': 'HEALTH CARE',
#   'latitude': 42.5769634,
#   'longitude': -70.9169998,
#   'year': 2018},
#  {'ticker': 'CMG',
#   'name': 'CHIPOTLE MEXICAN GRILL, INC.',
#   'yearly_value_change': 219.140014648437,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 33.6183291,
#   'longitude': -117.8724881,
#   'year': 2018},
#  {'ticker': 'ISRG',
#   'name': 'INTUITIVE SURGICAL, INC.',
#   'yearly_value_change': 212.53335571289102,
#   'sector': 'HEALTH CARE',
#   'latitude': 37.373002,
#   'longitude': -122.0040014,
#   'year': 2018},
#  {'ticker': 'GWW',
#   'name': 'W.W. GRAINGER, INC.',
#   'yearly_value_change': 203.26998901367196,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 42.2363993,
#   'longitude': -87.911161,
#   'year': 2018},
#  {'ticker': 'ALGN',
#   'name': 'ALIGN TECHNOLOGY, INC.',
#   'yearly_value_change': 193.60000610351602,
#   'sector': 'HEALTH CARE',
#   'latitude': 37.3903189,
#   'longitude': -121.9354487,
#   'year': 2018},
#  {'ticker': 'NFLX',
#   'name': 'NETFLIX, INC.',
#   'yearly_value_change': 188.960006713867,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 37.2593139,
#   'longitude': -121.9619835,
#   'year': 2018},
#  {'ticker': 'CACC',
#   'name': 'CREDIT ACCEPTANCE CORPORATION',
#   'yearly_value_change': 182.13000488281193,
#   'sector': 'FINANCE',
#   'latitude': 42.4999782,
#   'longitude': -83.29716959999999,
#   'year': 2018},
#  {'ticker': 'MED',
#   'name': 'MEDIFAST INC',
#   'yearly_value_change': 169.3899917602541,
#   'sector': 'CONSUMER NON-DURABLES',
#   'latitude': 39.2825875,
#   'longitude': -76.6016034,
#   'year': 2018},
#  {'ticker': 'SAM',
#   'name': 'BOSTON BEER COMPANY, INC. (THE)',
#   'yearly_value_change': 166.25001525878898,
#   'sector': 'CONSUMER NON-DURABLES',
#   'latitude': 42.3441918,
#   'longitude': -71.0336324,
#   'year': 2018},
#  {'ticker': 'SIVB',
#   'name': 'SVB FINANCIAL GROUP',
#   'yearly_value_change': 156.95999145507798,
#   'sector': 'FINANCE',
#   'latitude': 37.4042585,
#   'longitude': -121.982235,
#   'year': 2018},
#  {'ticker': 'INGN',
#   'name': 'INOGEN, INC',
#   'yearly_value_change': 151.7099914550783,
#   'sector': 'HEALTH CARE',
#   'latitude': 34.4276727,
#   'longitude': -119.8672596,
#   'year': 2018},
#  {'ticker': 'CSGP',
#   'name': 'COSTAR GROUP, INC.',
#   'yearly_value_change': 149.61999511718693,
#   'sector': 'MISCELLANEOUS',
#   'latitude': 38.9041034,
#   'longitude': -77.0311069,
#   'year': 2018},
#  {'ticker': 'ILMN',
#   'name': 'ILLUMINA, INC.',
#   'yearly_value_change': 147.40000915527403,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 32.8708716,
#   'longitude': -117.1990312,
#   'year': 2018},
#  {'ticker': 'ORLY',
#   'name': 'O&#39;REILLY AUTOMOTIVE, INC.',
#   'yearly_value_change': 135.95001220703097,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 37.20765919999999,
#   'longitude': -93.2492485,
#   'year': 2018},
#  {'ticker': 'ANET',
#   'name': 'ARISTA NETWORKS, INC.',
#   'yearly_value_change': 134.25997924804702,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.4118561,
#   'longitude': -121.9763085,
#   'year': 2018},
#  {'ticker': 'WCG',
#   'name': 'WELLCARE HEALTH PLANS, INC.',
#   'yearly_value_change': 132.579986572266,
#   'sector': 'HEALTH CARE',
#   'latitude': 28.0306431,
#   'longitude': -82.5488209,
#   'year': 2018},
#  {'ticker': 'CHE',
#   'name': 'CHEMED CORP.',
#   'yearly_value_change': 129.420013427735,
#   'sector': 'HEALTH CARE',
#   'latitude': 39.1016183,
#   'longitude': -84.50837159999999,
#   'year': 2018},
#  {'ticker': 'LGND',
#   'name': 'LIGAND PHARMACEUTICALS INCORPORATED',
#   'yearly_value_change': 124.000007629395,
#   'sector': 'HEALTH CARE',
#   'latitude': 32.9024599,
#   'longitude': -117.2207149,
#   'year': 2018},
#  {'ticker': 'MELI',
#   'name': 'MERCADOLIBRE, INC.',
#   'yearly_value_change': 122.97000122070304,
#   'sector': 'MISCELLANEOUS',
#   'latitude': -34.5472573,
#   'longitude': -58.4868316,
#   'year': 2018},
#  {'ticker': 'BA',
#   'name': 'BOEING COMPANY (THE)',
#   'yearly_value_change': 110.86000061035097,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 41.8841353,
#   'longitude': -87.63884270000001,
#   'year': 2018},
#  {'ticker': 'SHW',
#   'name': 'SHERWIN-WILLIAMS COMPANY (THE)',
#   'yearly_value_change': 110.57000732421898,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 41.4972774,
#   'longitude': -81.6924983,
#   'year': 2018},
#  {'ticker': 'ADBE',
#   'name': 'ADOBE SYSTEMS INCORPORATED',
#   'yearly_value_change': 110.29000854492202,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.3303074,
#   'longitude': -121.8941558,
#   'year': 2018},
#  {'ticker': 'DPZ',
#   'name': 'DOMINO&#39;S PIZZA INC',
#   'yearly_value_change': 109.97001647949199,
#   'sector': 'CONSUMER NON-DURABLES',
#   'latitude': 42.318938,
#   'longitude': -83.6812822,
#   'year': 2018},
#  {'ticker': 'RH',
#   'name': 'RH',
#   'yearly_value_change': 108.5199966430668,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 37.9181511,
#   'longitude': -122.5100465,
#   'year': 2018},
#  {'ticker': 'NVDA',
#   'name': 'NVIDIA CORPORATION',
#   'yearly_value_change': 105.11999511718702,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.3708002,
#   'longitude': -121.9673611,
#   'year': 2018},
#  {'ticker': 'BGNE',
#   'name': 'BEIGENE, LTD.',
#   'yearly_value_change': 102.22000122070263,
#   'sector': 'HEALTH CARE',
#   'latitude': 39.90419989999999,
#   'longitude': 116.4073963,
#   'year': 2018},
#  {'ticker': 'BIO',
#   'name': 'BIO-RAD LABORATORIES, INC.',
#   'yearly_value_change': 100.72001647949199,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 38.023058,
#   'longitude': -122.279823,
#   'year': 2018},
#  {'ticker': 'SRPT',
#   'name': 'SAREPTA THERAPEUTICS, INC.',
#   'yearly_value_change': 97.12000656127921,
#   'sector': 'HEALTH CARE',
#   'latitude': 42.364292,
#   'longitude': -71.0792115,
#   'year': 2018},
#  {'ticker': 'IDXX',
#   'name': 'IDEXX LABORATORIES, INC.',
#   'yearly_value_change': 96.0,
#   'sector': 'HEALTH CARE',
#   'latitude': 43.6615036,
#   'longitude': -70.3735631,
#   'year': 2018},
#  {'ticker': 'IAC',
#   'name': 'IAC/INTERACTIVECORP',
#   'yearly_value_change': 94.44000244140601,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 40.7455869,
#   'longitude': -74.00765670000001,
#   'year': 2018},
#  {'ticker': 'PANW',
#   'name': 'PALO ALTO NETWORKS, INC.',
#   'yearly_value_change': 94.099990844726,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.3836462,
#   'longitude': -121.9826432,
#   'year': 2018},
#  {'ticker': 'TDY',
#   'name': 'TELEDYNE TECHNOLOGIES INCORPORATED',
#   'yearly_value_change': 88.23001098632801,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 34.1974847,
#   'longitude': -118.9054586,
#   'year': 2018},
#  {'ticker': 'TTD',
#   'name': 'THE TRADE DESK, INC.',
#   'yearly_value_change': 87.8600044250492,
#   'sector': 'TECHNOLOGY',
#   'latitude': 34.2814477,
#   'longitude': -119.2913175,
#   'year': 2018},
#  {'ticker': 'FICO',
#   'name': 'FAIR ISAAC CORPORATION',
#   'yearly_value_change': 85.13999938964801,
#   'sector': 'MISCELLANEOUS',
#   'latitude': 37.3685081,
#   'longitude': -121.9186616,
#   'year': 2018},
#  {'ticker': 'MSG',
#   'name': 'THE MADISON SQUARE GARDEN COMPANY',
#   'yearly_value_change': 84.549987792969,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 40.7498317,
#   'longitude': -73.9916586,
#   'year': 2018},
#  {'ticker': 'WEX',
#   'name': 'WEX INC.',
#   'yearly_value_change': 83.73000335693301,
#   'sector': 'MISCELLANEOUS',
#   'latitude': 43.6603544,
#   'longitude': -70.2472189,
#   'year': 2018},
#  {'ticker': 'NOW',
#   'name': 'SERVICENOW, INC.',
#   'yearly_value_change': 83.48999786377,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.3759167,
#   'longitude': -121.9626911,
#   'year': 2018},
#  {'ticker': 'GRUB',
#   'name': 'GRUBHUB INC.',
#   'yearly_value_change': 82.8200035095212,
#   'sector': 'MISCELLANEOUS',
#   'latitude': 41.8829364,
#   'longitude': -87.6314575,
#   'year': 2018},
#  {'ticker': 'INTU',
#   'name': 'INTUIT INC.',
#   'yearly_value_change': 81.36000061035102,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.4306146,
#   'longitude': -122.0960646,
#   'year': 2018},
#  {'ticker': 'TDG',
#   'name': 'TRANSDIGM GROUP INCORPORATED',
#   'yearly_value_change': 79.94998168945295,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 41.5051402,
#   'longitude': -81.68953049999999,
#   'year': 2018},
#  {'ticker': 'HUM',
#   'name': 'HUMANA INC.',
#   'yearly_value_change': 78.77999877929696,
#   'sector': 'HEALTH CARE',
#   'latitude': 38.2558737,
#   'longitude': -85.7585738,
#   'year': 2018},
#  {'ticker': 'CTAS',
#   'name': 'CINTAS CORPORATION',
#   'yearly_value_change': 78.54000854492102,
#   'sector': 'CONSUMER NON-DURABLES',
#   'latitude': 39.3408406,
#   'longitude': -84.28298319999999,
#   'year': 2018},
#  {'ticker': 'LULU',
#   'name': 'LULULEMON ATHLETICA INC.',
#   'yearly_value_change': 78.009994506836,
#   'sector': 'CONSUMER NON-DURABLES',
#   'latitude': 49.27204380000001,
#   'longitude': -123.1469356,
#   'year': 2018},
#  {'ticker': 'MOH',
#   'name': 'MOLINA HEALTHCARE INC',
#   'yearly_value_change': 77.16999816894571,
#   'sector': 'HEALTH CARE',
#   'latitude': 33.7665116,
#   'longitude': -118.2006675,
#   'year': 2018},
#  {'ticker': 'PAYC',
#   'name': 'PAYCOM SOFTWARE, INC.',
#   'yearly_value_change': 76.55000305175759,
#   'sector': 'TECHNOLOGY',
#   'latitude': 35.6117324,
#   'longitude': -97.64861309999999,
#   'year': 2018},
#  {'ticker': 'MA',
#   'name': 'MASTERCARD INCORPORATED',
#   'yearly_value_change': 76.169998168945,
#   'sector': 'MISCELLANEOUS',
#   'latitude': 41.0208168,
#   'longitude': -73.7096826,
#   'year': 2018},
#  {'ticker': 'BURL',
#   'name': 'BURLINGTON STORES, INC.',
#   'yearly_value_change': 76.06999969482408,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 40.0925917,
#   'longitude': -74.8076866,
#   'year': 2018},
#  {'ticker': 'FLT',
#   'name': 'FLEETCOR TECHNOLOGIES, INC.',
#   'yearly_value_change': 75.669998168946,
#   'sector': 'MISCELLANEOUS',
#   'latitude': 33.9731121,
#   'longitude': -84.2242981,
#   'year': 2018},
#  {'ticker': 'NSP',
#   'name': 'INSPERITY, INC.',
#   'yearly_value_change': 75.5749969482421,
#   'sector': 'TECHNOLOGY',
#   'latitude': 30.0497309,
#   'longitude': -95.2499557,
#   'year': 2018},
#  {'ticker': 'PRLB',
#   'name': 'PROTO LABS, INC.',
#   'yearly_value_change': 75.4999923706051,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 45.0130732,
#   'longitude': -93.6634526,
#   'year': 2018},
#  {'ticker': 'AMED',
#   'name': 'AMEDISYS INC',
#   'yearly_value_change': 74.65999603271527,
#   'sector': 'HEALTH CARE',
#   'latitude': 30.4157875,
#   'longitude': -91.05493260000001,
#   'year': 2018},
#  {'ticker': 'USNA',
#   'name': 'USANA HEALTH SCIENCES, INC.',
#   'yearly_value_change': 74.2499923706051,
#   'sector': 'CONSUMER DURABLES',
#   'latitude': 40.7132655,
#   'longitude': -111.9807301,
#   'year': 2018},
#  {'ticker': 'SAGE',
#   'name': 'SAGE THERAPEUTICS, INC.',
#   'yearly_value_change': 72.68999481201149,
#   'sector': 'HEALTH CARE',
#   'latitude': 42.364292,
#   'longitude': -71.0792115,
#   'year': 2018},
#  {'ticker': 'MTN',
#   'name': 'VAIL RESORTS, INC.',
#   'yearly_value_change': 72.19998168945298,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 39.9253372,
#   'longitude': -105.115069,
#   'year': 2018},
#  {'ticker': 'FFIV',
#   'name': 'F5 NETWORKS, INC.',
#   'yearly_value_change': 71.379997253418,
#   'sector': 'TECHNOLOGY',
#   'latitude': 47.6051985,
#   'longitude': -122.3310207,
#   'year': 2018},
#  {'ticker': 'COST',
#   'name': 'COSTCO WHOLESALE CORPORATION',
#   'yearly_value_change': 71.27999877929699,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 47.5485708,
#   'longitude': -122.0506521,
#   'year': 2018},
#  {'ticker': 'TYL',
#   'name': 'TYLER TECHNOLOGIES, INC.',
#   'yearly_value_change': 70.509994506836,
#   'sector': 'TECHNOLOGY',
#   'latitude': 33.0657811,
#   'longitude': -96.8022754,
#   'year': 2018},
#  {'ticker': 'HUBS',
#   'name': 'HUBSPOT, INC.',
#   'yearly_value_change': 70.3000030517582,
#   'sector': 'TECHNOLOGY',
#   'latitude': 42.3697647,
#   'longitude': -71.0773545,
#   'year': 2018},
#  {'ticker': 'AAP',
#   'name': 'ADVANCE AUTO PARTS INC',
#   'yearly_value_change': 70.1800003051762,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 35.8489258,
#   'longitude': -78.5921791,
#   'year': 2018},
#  {'ticker': 'ANTM',
#   'name': 'ANTHEM, INC.',
#   'yearly_value_change': 70.16000366210898,
#   'sector': 'HEALTH CARE',
#   'latitude': 39.7635179,
#   'longitude': -86.1511072,
#   'year': 2018},
#  {'ticker': 'UNH',
#   'name': 'UNITEDHEALTH GROUP INCORPORATED',
#   'yearly_value_change': 69.72999572753898,
#   'sector': 'HEALTH CARE',
#   'latitude': 44.898716,
#   'longitude': -93.4437263,
#   'year': 2018},
#  {'ticker': 'CACI',
#   'name': 'CACI INTERNATIONAL, INC.',
#   'yearly_value_change': 67.550003051758,
#   'sector': 'TECHNOLOGY',
#   'latitude': 38.883444,
#   'longitude': -77.118044,
#   'year': 2018},
#  {'ticker': 'NBIX',
#   'name': 'NEUROCRINE BIOSCIENCES, INC.',
#   'yearly_value_change': 66.54999923706089,
#   'sector': 'HEALTH CARE',
#   'latitude': 32.949844,
#   'longitude': -117.237481,
#   'year': 2018},
#  {'ticker': 'ZBRA',
#   'name': 'ZEBRA TECHNOLOGIES CORPORATION',
#   'yearly_value_change': 65.910003662109,
#   'sector': 'TECHNOLOGY',
#   'latitude': 42.187545,
#   'longitude': -87.93350900000002,
#   'year': 2018},
#  {'ticker': 'FDS',
#   'name': 'FACTSET RESEARCH SYSTEMS INC.',
#   'yearly_value_change': 65.58999633789102,
#   'sector': 'TECHNOLOGY',
#   'latitude': 41.1467171,
#   'longitude': -73.4270264,
#   'year': 2018},
#  {'ticker': 'HAE',
#   'name': 'HAEMONETICS CORPORATION',
#   'yearly_value_change': 65.38000106811572,
#   'sector': 'HEALTH CARE',
#   'latitude': 42.3530628,
#   'longitude': -71.05750739999999,
#   'year': 2018},
#  {'ticker': 'ROP',
#   'name': 'ROPER TECHNOLOGIES, INC.',
#   'yearly_value_change': 65.059997558594,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 27.3837107,
#   'longitude': -82.4317818,
#   'year': 2018},
#  {'ticker': 'ANAB',
#   'name': 'ANAPTYSBIO, INC.',
#   'yearly_value_change': 64.61000251770011,
#   'sector': 'HEALTH CARE',
#   'latitude': 32.9061204,
#   'longitude': -117.1878408,
#   'year': 2018},
#  {'ticker': 'FIVE',
#   'name': 'FIVE BELOW, INC.',
#   'yearly_value_change': 64.12000274658172,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 39.95129370000001,
#   'longitude': -75.1526227,
#   'year': 2018},
#  {'ticker': 'LIVN',
#   'name': 'LIVANOVA PLC',
#   'yearly_value_change': 63.9099998474125,
#   'sector': 'HEALTH CARE',
#   'latitude': 51.5167017,
#   'longitude': -0.1790091,
#   'year': 2018},
#  {'ticker': 'TRHC',
#   'name': 'TABULA RASA HEALTHCARE, INC.',
#   'yearly_value_change': 63.3399963378906,
#   'sector': 'MISCELLANEOUS',
#   'latitude': 39.9516,
#   'longitude': -74.9492999,
#   'year': 2018},
#  {'ticker': 'SPLK',
#   'name': 'SPLUNK INC.',
#   'yearly_value_change': 63.010002136230206,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.7827679,
#   'longitude': -122.3913735,
#   'year': 2018},
#  {'ticker': 'BLUE',
#   'name': 'BLUEBIRD BIO, INC.',
#   'yearly_value_change': 61.849998474120895,
#   'sector': 'HEALTH CARE',
#   'latitude': 42.365026,
#   'longitude': -71.079815,
#   'year': 2018},
#  {'ticker': 'WWE',
#   'name': 'WORLD WRESTLING ENTERTAINMENT, INC.',
#   'yearly_value_change': 61.45999717712401,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 41.0592289,
#   'longitude': -73.5097026,
#   'year': 2018},
#  {'ticker': 'MSCI',
#   'name': 'MSCI INC',
#   'yearly_value_change': 61.17000579834003,
#   'sector': 'MISCELLANEOUS',
#   'latitude': 40.7134166,
#   'longitude': -74.0119311,
#   'year': 2018},
#  {'ticker': 'DXCM',
#   'name': 'DEXCOM, INC.',
#   'yearly_value_change': 61.1699981689456,
#   'sector': 'HEALTH CARE',
#   'latitude': 32.9070685,
#   'longitude': -117.1859372,
#   'year': 2018},
#  {'ticker': 'W',
#   'name': 'WAYFAIR INC.',
#   'yearly_value_change': 60.97999572753922,
#   'sector': 'CONSUMER SERVICES',
#   'latitude': 42.3487196,
#   'longitude': -71.0772192,
#   'year': 2018},
#  {'ticker': 'EPAM',
#   'name': 'EPAM SYSTEMS, INC.',
#   'yearly_value_change': 60.569999694824205,
#   'sector': 'TECHNOLOGY',
#   'latitude': 40.2227953,
#   'longitude': -74.90580539999999,
#   'year': 2018},
#  {'ticker': 'CNC',
#   'name': 'CENTENE CORPORATION',
#   'yearly_value_change': 59.1700057983398,
#   'sector': 'HEALTH CARE',
#   'latitude': 38.6495116,
#   'longitude': -90.3345013,
#   'year': 2018},
#  {'ticker': 'TMO',
#   'name': 'THERMO FISHER SCIENTIFIC INC',
#   'yearly_value_change': 58.88999938964798,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 42.3929224,
#   'longitude': -71.26159430000001,
#   'year': 2018},
#  {'ticker': 'BIIB',
#   'name': 'BIOGEN INC.',
#   'yearly_value_change': 58.669982910157046,
#   'sector': 'HEALTH CARE',
#   'latitude': 42.3662897,
#   'longitude': -71.0857637,
#   'year': 2018},
#  {'ticker': 'CRM',
#   'name': 'SALESFORCE.COM INC',
#   'yearly_value_change': 58.60000610351581,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.7897442,
#   'longitude': -122.3972337,
#   'year': 2018},
#  {'ticker': 'BLK',
#   'name': 'BLACKROCK, INC.',
#   'yearly_value_change': 58.14001464843699,
#   'sector': 'FINANCE',
#   'latitude': 40.75923909999999,
#   'longitude': -73.97354829999999,
#   'year': 2018},
#  {'ticker': 'JKHY',
#   'name': 'JACK HENRY & ASSOCIATES, INC.',
#   'yearly_value_change': 57.95999908447297,
#   'sector': 'TECHNOLOGY',
#   'latitude': 36.9141117,
#   'longitude': -93.93882699999999,
#   'year': 2018},
#  {'ticker': 'BR',
#   'name': 'BROADRIDGE FINANCIAL SOLUTIONS, INC.',
#   'yearly_value_change': 57.099998474121406,
#   'sector': 'MISCELLANEOUS',
#   'latitude': 40.7620332,
#   'longitude': -73.6906851,
#   'year': 2018},
#  {'ticker': 'LII',
#   'name': 'LENNOX INTERNATIONAL, INC.',
#   'yearly_value_change': 57.08999633789102,
#   'sector': 'CAPITAL GOODS',
#   'latitude': 32.9817034,
#   'longitude': -96.76028749999999,
#   'year': 2018},
#  {'ticker': 'NEWR',
#   'name': 'NEW RELIC, INC.',
#   'yearly_value_change': 56.970001220703,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.7913249,
#   'longitude': -122.3929712,
#   'year': 2018},
#  {'ticker': 'POOL',
#   'name': 'POOL CORPORATION',
#   'yearly_value_change': 56.800003051758,
#   'sector': 'CONSUMER DURABLES',
#   'latitude': 30.44164719999999,
#   'longitude': -90.0873601,
#   'year': 2018},
#  {'ticker': 'BDX',
#   'name': 'BECTON, DICKINSON AND COMPANY',
#   'yearly_value_change': 56.72000122070301,
#   'sector': 'HEALTH CARE',
#   'latitude': 41.017009,
#   'longitude': -74.2106872,
#   'year': 2018},
#  {'ticker': 'DECK',
#   'name': 'DECKERS OUTDOOR CORPORATION',
#   'yearly_value_change': 55.8199996948239,
#   'sector': 'CONSUMER NON-DURABLES',
#   'latitude': 34.4287369,
#   'longitude': -119.8629881,
#   'year': 2018},
#  {'ticker': 'NSC',
#   'name': 'NORFOLK SOUTHER CORPORATION',
#   'yearly_value_change': 55.800003051758,
#   'sector': 'TRANSPORTATION',
#   'latitude': 36.8454996,
#   'longitude': -76.2880966,
#   'year': 2018},
#  {'ticker': 'AAPL',
#   'name': 'APPLE INC.',
#   'yearly_value_change': 55.73001098632801,
#   'sector': 'TECHNOLOGY',
#   'latitude': 37.334801,
#   'longitude': -122.0090499,
#   'year': 2018}]

# %%
stock_list = [stock['sector'] for stock in stock_growth_data]
stock_set = set(stock_list)

# %%
stock_set
# Out:
# {'BASIC INDUSTRIES',
#  'CAPITAL GOODS',
#  'CONSUMER DURABLES',
#  'CONSUMER NON-DURABLES',
#  'CONSUMER SERVICES',
#  'ENERGY',
#  'FINANCE',
#  'HEALTH CARE',
#  'MISCELLANEOUS',
#  'PUBLIC UTILITIES',
#  'TECHNOLOGY',
#  'TRANSPORTATION'}

# %%
len(stock_set)
# Out:
# 12
