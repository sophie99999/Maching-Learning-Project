# %%
import pandas as pd

# %%
five_year=pd.read_csv('../five_year.csv')

# %%
# Extract Apple stock
five_year=five_year.loc[five_year['ticker'] == 'AAPL']
five_year.head()
#five_year.shape
# Out:
#             name ticker       open      close  adj_close        low  \
# 2     APPLE INC.   AAPL  79.117142  78.432854  56.118870  77.375717
# 403   APPLE INC.   AAPL  78.268570  77.442856  55.410530  77.285713
# 803   APPLE INC.   AAPL  76.709999  75.285713  53.867073  75.118568
# 1202  APPLE INC.   AAPL  74.571426  74.842857  53.550209  73.599998
# 1601  APPLE INC.   AAPL  75.601425  75.044289  53.694336  74.464287
#
#            high     volume market_signal
# 2     79.285713  140129500          sell
# 403   78.524284   88241300          sell
# 803   76.947144  148583400          sell
# 1202  75.614288  121039100           buy
# 1601  75.984283  114676800          sell

# %%
# Set features. This will be used as X values.
feature=five_year[["open","close","adj_close","low","high","volume"]]

# Target values will come from "market_signal" column
target=five_year["market_signal"]

print(feature.shape,target.shape)
# Out:
# (1423, 6) (1423,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(feature,target,random_state=10,stratify=target)

# %%
# Scale the data by using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler().fit(X_train)
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

# %%
# KNN model

from sklearn.neighbors import KNeighborsClassifier

import matplotlib.pyplot as plt
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train_score = knn.score(X_train, y_train)
    test_score = knn.score(X_test, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
    
    
plt.plot(range(1, 20, 2), train_scores, marker='o')
plt.plot(range(1, 20, 2), test_scores, marker="x")
plt.xlabel("k neighbors")
plt.ylabel("Testing accuracy Score")
plt.show()
# Out:
# k: 1, Train/Test Score: 1.000/0.629
# k: 3, Train/Test Score: 0.797/0.590
# k: 5, Train/Test Score: 0.742/0.624
# k: 7, Train/Test Score: 0.708/0.576
# k: 9, Train/Test Score: 0.711/0.573
# k: 11, Train/Test Score: 0.665/0.556
# k: 13, Train/Test Score: 0.667/0.562
# k: 15, Train/Test Score: 0.648/0.567
# k: 17, Train/Test Score: 0.638/0.537
# k: 19, Train/Test Score: 0.630/0.534

# %%
# Using KNN model here. According to the graph above, the model has the best score when K is around 5
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
print('k=13 Test Acc: %.3f' % knn.score(X_test, y_test))
# Out:
# k=13 Test Acc: 0.624

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors':[5,6,7,8,9,10],
          'leaf_size':[1,2,3,5],
          'weights':['uniform', 'distance'],
          'algorithm':['auto', 'ball_tree','kd_tree','brute'],
          'n_jobs':[-1]}


grid=GridSearchCV(knn,param_grid,verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.631, total=   1.3s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.509, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.526, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance, score=0.640, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance, score=0.570, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance, score=0.601, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance, score=0.554, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.612, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.528, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.592, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance, score=0.612, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance, score=0.547, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance, score=0.610, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.500, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=distance, score=0.636, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=distance, score=0.551, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=distance, score=0.582, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=7, weights=distance, score=0.573, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.570, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.523, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.563, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=distance, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=distance, score=0.547, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=distance, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=8, weights=distance, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.467, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.610, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.498, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.587, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=distance, score=0.617, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=distance, score=0.533, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=distance, score=0.615, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=distance, score=0.540, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=9, weights=distance, score=0.592, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.579, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.528, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.577, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=distance, score=0.598, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=distance, score=0.542, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=distance, score=0.620, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=distance, score=0.554, total=   0.0s
# [CV] algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=1, n_jobs=-1, n_neighbors=10, weights=distance, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.631, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.509, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.526, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=distance, score=0.640, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=distance, score=0.570, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=distance, score=0.601, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=distance, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=5, weights=distance, score=0.554, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.612, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.528, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.592, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=distance, score=0.612, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=distance, score=0.547, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=distance, score=0.610, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.500, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.636, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.551, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.582, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=7, weights=distance, score=0.573, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.570, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.523, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.563, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=distance, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=distance, score=0.547, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=distance, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=8, weights=distance, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.467, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.610, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.498, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.587, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=distance, score=0.617, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=distance, score=0.533, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=distance, score=0.615, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=distance, score=0.540, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=9, weights=distance, score=0.592, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.579, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.528, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.577, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=distance, score=0.598, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=distance, score=0.542, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=distance, score=0.620, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=distance, score=0.554, total=   0.0s
# [CV] algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=2, n_jobs=-1, n_neighbors=10, weights=distance, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.631, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.509, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.526, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=distance, score=0.640, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=distance, score=0.570, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=distance, score=0.601, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=distance, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=5, weights=distance, score=0.554, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.612, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.528, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.592, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=distance, score=0.612, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=distance, score=0.547, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=distance, score=0.610, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.500, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.636, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.551, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.582, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=7, weights=distance, score=0.573, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.570, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.523, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.563, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance, score=0.547, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.467, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.610, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.498, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.587, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance, score=0.617, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance, score=0.533, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance, score=0.615, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance, score=0.540, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance, score=0.592, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.579, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.528, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.577, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance, score=0.598, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance, score=0.542, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance, score=0.620, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance, score=0.554, total=   0.0s
# [CV] algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.631, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.509, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.526, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance, score=0.640, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance, score=0.570, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance, score=0.601, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance, score=0.554, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.612, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.528, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.592, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.516, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance, score=0.612, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance, score=0.547, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance, score=0.610, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.500, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.636, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.551, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.582, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.573, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.570, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.523, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.563, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance, score=0.547, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance, score=0.596, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance, score=0.568, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance, score=0.559, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.593, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.467, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.610, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.498, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.587, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance, score=0.617, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance, score=0.533, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance, score=0.615, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance, score=0.540, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance, score=0.592, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.579, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.528, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.545, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.577, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance, score=0.598, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance, score=0.542, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance, score=0.620, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance, score=0.554, total=   0.0s
# [CV] algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=auto, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance, score=0.596, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.631, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.509, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.596, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.516, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.526, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance, score=0.640, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance, score=0.570, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance, score=0.601, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance, score=0.516, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=5, weights=distance, score=0.554, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.528, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.592, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.516, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.535, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance, score=0.612, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance, score=0.547, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance, score=0.610, total=   0.0s
# [CV] algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=ball_tree, leaf_size=1, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.0s
# ...
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=8, weights=distance, score=0.559, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.593, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.467, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.610, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.498, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.587, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance, score=0.617, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance, score=0.533, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance, score=0.615, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance, score=0.540, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=9, weights=distance, score=0.592, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.579, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.528, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.545, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.535, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.577, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance, score=0.598, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance, score=0.542, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance, score=0.620, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance, score=0.554, total=   0.1s
# [CV] algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=brute, leaf_size=3, n_jobs=-1, n_neighbors=10, weights=distance, score=0.596, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.631, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.509, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.596, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.516, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=uniform, score=0.526, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance, score=0.640, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance, score=0.570, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance, score=0.601, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance, score=0.516, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=5, weights=distance, score=0.554, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.612, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.528, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.592, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.516, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=uniform, score=0.535, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance, score=0.612, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance, score=0.547, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance, score=0.610, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=6, weights=distance, score=0.568, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.593, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.500, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.559, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.535, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=uniform, score=0.545, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.636, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.551, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.582, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.568, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=7, weights=distance, score=0.573, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.570, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.523, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.563, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.545, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=uniform, score=0.559, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance, score=0.593, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance, score=0.547, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance, score=0.596, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance, score=0.568, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=8, weights=distance, score=0.559, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.593, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.467, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.610, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.498, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=uniform, score=0.587, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance, score=0.617, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance, score=0.533, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance, score=0.615, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance, score=0.540, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=9, weights=distance, score=0.592, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.579, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.528, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.545, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.535, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=uniform, score=0.577, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance, score=0.598, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance, score=0.542, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance, score=0.620, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance, score=0.554, total=   0.1s
# [CV] algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance
# [CV]  algorithm=brute, leaf_size=5, n_jobs=-1, n_neighbors=10, weights=distance, score=0.596, total=   0.1s
# [Parallel(n_jobs=1)]: Done 960 out of 960 | elapsed:   43.7s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [1, 2, 3, 5], 'n_jobs': [-1],
#                          'n_neighbors': [5, 6, 7, 8, 9, 10],
#                          'weights': ['uniform', 'distance']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'algorithm': 'auto', 'leaf_size': 1, 'n_jobs': -1, 'n_neighbors': 10, 'weights': 'distance'}
# 0.5820279935062086

# %%
predictions=grid.predict(X_test)
# Classificaiton report 
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions,target_names=["buy","sell"]))

from sklearn import metrics
#evaluation(Accuracy)
print("Accuracy:",metrics.accuracy_score(predictions,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          buy       0.62      0.65      0.64       185
#         sell       0.60      0.57      0.58       171
#
#     accuracy                           0.61       356
#    macro avg       0.61      0.61      0.61       356
# weighted avg       0.61      0.61      0.61       356
#
# Accuracy: 0.6123595505617978

# %%
# Save the model 
import joblib
filename = 'saved models/KNN.sav'
joblib.dump(grid, filename)
# Out:
# ['saved models/KNN.sav']
